# %% [markdown]
# <a href="https://colab.research.google.com/github/Geek-a-Byte/covid-data-visualization-using-python-matplotlib/blob/main/covid_19_data_visualization(simple_plot).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **must run the this block to import pandas and matplotlib**

# %%
import pandas as pd;
import matplotlib.pyplot as plt

# %% [markdown]
# # **Simple Plot**

# %%
data = pd.read_csv('case_time_series.csv')
# data
# We will be collecting 
# C=Daily Confirmed  
# R=Daily Recovered 
# D=Daily Deceased in variables as array.

# to know about iloc - https://www.w3schools.com/python/pandas/ref_df_iloc.asp
# remember that x,y index are 0-based 
# so here 61 actually means 63th data of csv

Y = data.iloc[61:,1].values #Stores Daily Confirmed
# Y
# array([ 309,  424,  486,  560,  579,  609,  484,  573,  565,  813,  871,
#         854,  758, 1243, 1031,  886, 1061,  922, 1371, 1580, 1239, 1537,
#        1292, 1667, 1408, 1835, 1607, 1568, 1902, 1705, 1801, 2396, 2564,
#        2952, 3656, 2971, 3602, 3344, 3339, 3175, 4311, 3592, 3562, 3726])

R = data.iloc[61:,3].values #Stores Daily Recovered
# R
# array([  13,   19,   22,   39,   56,   43,   65,   75,   96,   70,  151,
#         186,  114,  112,  167,  144,  258,  273,  426,  388,  419,  703,
#         394,  642,  484,  442,  585,  580,  636,  690,  630,  962,  831,
#         911, 1082, 1295, 1161, 1475, 1111, 1414, 1669, 1579, 1905, 1964])

D = data.iloc[61:,5].values #Stores Daily Deceased
# D
# array([  6,   6,  16,  14,  13,  22,  16,  27,  20,  46,  22,  41,  42,
#         27,  37,  27,  26,  38,  35,  38,  33,  53,  36,  40,  59,  44,
#         56,  58,  69,  71,  75,  77,  92, 140, 103, 128,  91, 104,  97,
#        115, 112,  81, 120, 136])

X = data.iloc[61:,0].values #Stores Date
# X
# array(['31 March ', '01 April ', '02 April ', '03 April ', '04 April ',
#        '05 April ', '06 April ', '07 April ', '08 April ', '09 April ',
#        '10 April ', '11 April ', '12 April ', '13 April ', '14 April ',
#        '15 April ', '16 April ', '17 April ', '18 April ', '19 April ',
#        '20 April ', '21 April ', '22 April ', '23 April ', '24 April ',
#        '25 April ', '26 April ', '27 April ', '28 April ', '29 April ',
#        '30 April ', '01 May ', '02 May ', '03 May ', '04 May ', '05 May ',
#        '06 May ', '07 May ', '08 May ', '09 May ', '10 May ', '11 May ',
#        '12 May ', '13 May '], dtype=object)

plt.plot(X,Y)

# %% [markdown]
# We get a Simple Plot on the execution of above code which looks like this where X-axis has Dates and Y-axis has Number of Confirmed cases. But this is not the best representation for large dataset values along the axes as you can see the ‘Dates’ are overlapping on X-axis. To overcome this challenge we will introduce some new functions to take more control over the aesthetics of the graph.

# %% [markdown]
# ## **Aesthetics**

# %%
# This creates a canvas for the graph 
# where the first value ‘25’ is the width argument position and 
# ‘8’ is the height argument position of the graph.
plt.figure(figsize=(25,8))

# Let’s create an object of the axes of the graph as ‘ax’ so it becomes easier to implement functions.
ax = plt.axes()
# ‘.grid’ function lets you create grid lines across the graph. 
# The width(boldness) of the grid lines can be adjusted by simply passing an argument ‘linewidth’ 
# and changing its color by passing ‘color’ argument.
ax.grid(linewidth=0.4, color='#8f8f8f') 

# ‘.set_facecolor’ lets you set the background color of the graph which over here is black.
ax.set_facecolor("black") 
# ‘.set_xlabel’ and ‘.set_ylabel’ lets you set the label along both axes whose size and color can be altered .
ax.set_xlabel('\nDate',size=25,color='#4bb4f2')
ax.set_ylabel('Number of Confirmed Cases\n',size=25,color='#4bb4f2')

# Now we plot the graph again with ‘X’ as Dates and ‘Y’ as Daily Confirmed by calling plot function.
#  color - changes the color 
#  linewidth - adjust the width of plotting line 
#  marker to create marker which is the circle in this case 
#  markersize - adjust the size of the marker and 
#  markeredgecolor - define marker’s edge color.
ax.plot(X,Y,
        color='#0C1446', # Royal Blue
        marker='o',
        linewidth=4,
        markersize=15,
        markeredgecolor='#87ACA3') # Seafoam Green

# %% [markdown]
# Still as we can see the dates are overlapping and the labels along axes are not clear enough. So now we are going to change the ticks of the axes and also annotate the plots.

# %% [markdown]
# # **Final code**

# %%
plt.figure(figsize=(25,8))
ax = plt.axes()
ax.grid(linewidth=0.4, color='#8f8f8f') 
ax.set_facecolor("black") 
ax.set_xlabel('\nDate',size=25,color='#4bb4f2')
ax.set_ylabel('Number of Confirmed Cases\n',size=25,color='#4bb4f2')

# ‘.xticks’ and ‘.yticks’ lets you alter the Dates and Daily Confirmed font. 
# For the Dates to not overlap with each other we are going to represent them vertically by passing ‘rotation = vertical’.
# To make the ticks easily readable we change the font color to black and size to 20.
plt.xticks(rotation='vertical',size='20',color='black')
plt.yticks(size=20,color='black')
plt.tick_params(size=20,color='black')

ax.plot(X,Y,
        color='#0C1446', # Royal Blue
        marker='o',
        linewidth=4,
        markersize=15,
        markeredgecolor='#87ACA3') # Seafoam Green

# ‘.annotate’ lets you annotate on the graph. 
# Over here we have written a code to annotate the plotted points by running a for loop which plots at the plotted points.
# The str(j) holds the ‘Y’ variable which is Daily Confirmed. Any string passed will be plotted. 
# The XY is the coordinates where the string should be plotted. 
# And finally the color and size can be defined. 
# Note we have added +100 to j in XY coordinates so that the string doesn’t overlap with the marker and it is at the distance of 100 units on Y-axis.
for i,j in zip(X,Y):
    ax.annotate(str(j),xy=(i,j+100),color='white',size='13')

# To annotate an arrow pointing at a position in graph and its tail holding the string we can define ‘arrowprops’ argument 
# along with its head coordinates defined by ‘xy’ and tail coordinates defined by ‘xytext’. 
# Note that ‘arrowprops’ alteration can be done using a dictionary.
ax.annotate('Second Lockdown 15th April',
            xy=(15.2, 860),
            xytext=(19.9,500),
            color='white',
            size='25',
            arrowprops=dict(color='white',linewidth=0.08))

plt.title("COVID-19 IN : Daily Confirmed\n",size=50,color='#28a9ff')
# Out:
# Text(0.5, 1.0, 'COVID-19 IN : Daily Confirmed\n')

# %% [markdown]
# # **additional knowlegde**

# %% [markdown]
# **knowledge about python func zip()**

# %% [markdown]
# Traversing Lists in Parallel
# Python’s zip() function allows you to iterate in parallel over two or more iterables. Since zip() generates tuples, you can unpack these in the header of a for loop:

# %%
letters = ['a', 'b', 'c']
numbers = [0, 1, 2]
for l, n in zip(letters, numbers):
    print(f'Letter: {l}')
    print(f'Number: {n}')

letters = ['a', 'b', 'c']
numbers = [0, 1, 2]
operators = ['*', '/', '+']
for l, n, o in zip(letters, numbers, operators):
    print(f'Letter: {l}')
    print(f'Number: {n}')
    print(f'Operator: {o}')

# %% [markdown]
# Here, you iterate through the series of tuples returned by zip() and unpack the elements into l and n. When you combine zip(), for loops, and tuple unpacking, you can get a useful and Pythonic idiom for traversing two or more iterables at once.
#
# You can also iterate through more than two iterables in a single for loop. Consider the following example, which has three input iterables
